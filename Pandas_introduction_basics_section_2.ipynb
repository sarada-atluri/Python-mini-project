# %% [markdown]
# <a href="https://colab.research.google.com/github/sarada-atluri/Python-mini-project/blob/main/Pandas_introduction_basics_section_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
age = []
height = []
weight = []
speed = []
for _ in range(100):
   age.append(random.randint(0,100))
   height.append(random.randint(0,100))
   weight.append(random.randint(0,100))
   speed.append(random.randint(0,100))

idata ={'Age':age, 'Height':height, 'Weight':weight, 'Speed':speed}

# %%
idata
# Out:
# {'Age': [35,
#   0,
#   90,
#   38,
#   1,
#   45,
#   49,
#   56,
#   43,
#   64,
#   10,
#   98,
#   84,
#   0,
#   30,
#   74,
#   21,
#   17,
#   17,
#   76,
#   78,
#   47,
#   87,
#   81,
#   41,
#   27,
#   20,
#   37,
#   76,
#   82,
#   93,
#   25,
#   97,
#   86,
#   16,
#   94,
#   8,
#   54,
#   80,
#   3,
#   90,
#   10,
#   99,
#   21,
#   68,
#   87,
#   38,
#   14,
#   8,
#   88,
#   88,
#   82,
#   69,
#   50,
#   96,
#   87,
#   88,
#   65,
#   8,
#   48,
#   13,
#   4,
#   21,
#   91,
#   64,
#   86,
#   67,
#   65,
#   84,
#   49,
#   91,
#   57,
#   43,
#   59,
#   11,
#   53,
#   1,
#   15,
#   4,
#   55,
#   36,
#   90,
#   95,
#   57,
#   18,
#   27,
#   59,
#   23,
#   81,
#   44,
#   67,
#   10,
#   21,
#   60,
#   3,
#   54,
#   79,
#   23,
#   55,
#   73],
#  'Height': [5,
#   6,
#   91,
#   54,
#   13,
#   86,
#   26,
#   30,
#   35,
#   20,
#   60,
#   1,
#   89,
#   71,
#   46,
#   53,
#   20,
#   47,
#   75,
#   100,
#   38,
#   92,
#   1,
#   41,
#   29,
#   52,
#   99,
#   0,
#   79,
#   60,
#   69,
#   25,
#   81,
#   52,
#   35,
#   13,
#   67,
#   95,
#   56,
#   83,
#   100,
#   13,
#   17,
#   7,
#   60,
#   77,
#   52,
#   62,
#   70,
#   45,
#   17,
#   94,
#   15,
#   5,
#   74,
#   83,
#   73,
#   46,
#   59,
#   5,
#   42,
#   25,
#   60,
#   42,
#   69,
#   67,
#   80,
#   60,
#   91,
#   59,
#   81,
#   20,
#   60,
#   56,
#   45,
#   0,
#   5,
#   8,
#   80,
#   3,
#   92,
#   28,
#   9,
#   33,
#   27,
#   76,
#   53,
#   38,
#   17,
#   87,
#   75,
#   18,
#   24,
#   92,
#   23,
#   6,
#   65,
#   21,
#   78,
#   95],
#  'Weight': [46,
#   97,
#   37,
#   5,
#   33,
#   95,
#   50,
#   30,
#   3,
#   41,
#   77,
#   40,
#   40,
#   98,
#   6,
#   36,
#   58,
#   54,
#   36,
#   89,
#   13,
#   71,
#   23,
#   39,
#   42,
#   62,
#   83,
#   4,
#   88,
#   51,
#   30,
#   41,
#   38,
#   79,
#   1,
#   51,
#   78,
#   16,
#   88,
#   85,
#   99,
#   15,
#   17,
#   67,
#   38,
#   7,
#   18,
#   41,
#   23,
#   4,
#   89,
#   63,
#   83,
#   97,
#   80,
#   27,
#   14,
#   67,
#   84,
#   96,
#   83,
#   100,
#   34,
#   45,
#   24,
#   68,
#   32,
#   48,
#   15,
#   36,
#   77,
#   91,
#   37,
#   63,
#   62,
#   88,
#   11,
#   4,
#   27,
#   48,
#   85,
#   78,
#   12,
#   74,
#   93,
#   37,
#   37,
#   44,
#   64,
#   60,
#   23,
#   14,
#   49,
#   83,
#   11,
#   66,
#   37,
#   80,
#   54,
#   32],
#  'Speed': [70,
#   41,
#   79,
#   26,
#   43,
#   100,
#   86,
#   95,
#   35,
#   43,
#   55,
#   93,
#   5,
#   39,
#   14,
#   28,
#   30,
#   5,
#   54,
#   90,
#   84,
#   11,
#   15,
#   29,
#   76,
#   33,
#   63,
#   79,
#   33,
#   64,
#   19,
#   52,
#   40,
#   30,
#   82,
#   15,
#   38,
#   100,
#   25,
#   88,
#   79,
#   9,
#   74,
#   30,
#   62,
#   79,
#   44,
#   46,
#   27,
#   90,
#   11,
#   79,
#   63,
#   34,
#   93,
#   27,
#   78,
#   33,
#   34,
#   66,
#   100,
#   28,
#   55,
#   34,
#   41,
#   9,
#   93,
#   82,
#   6,
#   31,
#   90,
#   52,
#   54,
#   92,
#   13,
#   61,
#   9,
#   33,
#   100,
#   46,
#   90,
#   58,
#   1,
#   10,
#   88,
#   41,
#   47,
#   58,
#   73,
#   67,
#   93,
#   5,
#   22,
#   62,
#   11,
#   93,
#   29,
#   33,
#   54,
#   77]}

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    35       5      46     70
# 1     0       6      97     41
# 2    90      91      37     79
# 3    38      54       5     26
# 4     1      13      33     43
# ..  ...     ...     ...    ...
# 95   54       6      66     93
# 96   79      65      37     29
# 97   23      21      80     33
# 98   55      78      54     54
# 99   73      95      32     77
#
# [100 rows x 4 columns]

# %%
df1.head(10)
# Out:
#    Age  Height  Weight  Speed
# 0   35       5      46     70
# 1    0       6      97     41
# 2   90      91      37     79
# 3   38      54       5     26
# 4    1      13      33     43
# 5   45      86      95    100
# 6   49      26      50     86
# 7   56      30      30     95
# 8   43      35       3     35
# 9   64      20      41     43

# %%
df1.tail(10)
# Out:
#     Age  Height  Weight  Speed
# 90   67      75      23     93
# 91   10      18      14      5
# 92   21      24      49     22
# 93   60      92      83     62
# 94    3      23      11     11
# 95   54       6      66     93
# 96   79      65      37     29
# 97   23      21      80     33
# 98   55      78      54     54
# 99   73      95      32     77

# %%
df1.describe()
# Out:
#              Age      Height      Weight       Speed
# count  100.00000  100.000000  100.000000  100.000000
# mean    50.92000   48.790000   50.090000   51.060000
# std     30.98637   30.085499   28.915444   29.076639
# min      0.00000    0.000000    1.000000    1.000000
# 25%     21.00000   20.750000   29.250000   29.000000
# 50%     54.00000   52.000000   45.500000   46.500000
# 75%     81.00000   75.000000   78.000000   79.000000
# max     99.00000  100.000000  100.000000  100.000000

# %%
df1[['Age', 'Height']]
# Out:
#     Age  Height
# 0    35       5
# 1     0       6
# 2    90      91
# 3    38      54
# 4     1      13
# ..  ...     ...
# 95   54       6
# 96   79      65
# 97   23      21
# 98   55      78
# 99   73      95
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age', 'Height']]
# Out:
#    Age  Height
# 0   35       5
# 3   38      54

# %%
df2 = df1[['Age', 'Height']]

# %%
df2
# Out:
#     Age  Height
# 0    35       5
# 1     0       6
# 2    90      91
# 3    38      54
# 4     1      13
# ..  ...     ...
# 95   54       6
# 96   79      65
# 97   23      21
# 98   55      78
# 99   73      95
#
# [100 rows x 2 columns]

# %%
df2.describe()
# Out:
#              Age      Height
# count  100.00000  100.000000
# mean    50.92000   48.790000
# std     30.98637   30.085499
# min      0.00000    0.000000
# 25%     21.00000   20.750000
# 50%     54.00000   52.000000
# 75%     81.00000   75.000000
# max     99.00000  100.000000

# %%
df1.sort_index(ascending = True)
# Out:
#     Age  Height  Weight  Speed
# 0    35       5      46     70
# 1     0       6      97     41
# 2    90      91      37     79
# 3    38      54       5     26
# 4     1      13      33     43
# ..  ...     ...     ...    ...
# 95   54       6      66     93
# 96   79      65      37     29
# 97   23      21      80     33
# 98   55      78      54     54
# 99   73      95      32     77
#
# [100 rows x 4 columns]

# %%
df1[0::2].describe()
# Out:
#              Age      Height     Weight       Speed
# count  50.000000   50.000000  50.000000   50.000000
# mean   50.820000   52.540000  45.640000   51.600000
# std    33.347086   28.441282  28.555538   29.853383
# min     1.000000    1.000000   1.000000    1.000000
# 25%    18.500000   26.250000  23.000000   27.500000
# 50%    52.000000   59.500000  37.500000   54.000000
# 75%    83.250000   75.000000  77.000000   78.750000
# max    99.000000  100.000000  99.000000  100.000000

# %%
# filter
filter1 = df1['Weight'] > 50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1     0       6      97     41
# 5    45      86      95    100
# 10   10      60      77     55
# 13    0      71      98     39
# 16   21      20      58     30
# 17   17      47      54      5
# 19   76     100      89     90
# 21   47      92      71     11
# 25   27      52      62     33
# 26   20      99      83     63
# 28   76      79      88     33
# 29   82      60      51     64
# 33   86      52      79     30
# 35   94      13      51     15
# 36    8      67      78     38
# 38   80      56      88     25
# 39    3      83      85     88
# 40   90     100      99     79
# 43   21       7      67     30
# 50   88      17      89     11
# 51   82      94      63     79
# 52   69      15      83     63
# 53   50       5      97     34
# 54   96      74      80     93
# 57   65      46      67     33
# 58    8      59      84     34
# 59   48       5      96     66
# 60   13      42      83    100
# 61    4      25     100     28
# 65   86      67      68      9
# 70   91      81      77     90
# 71   57      20      91     52
# 73   59      56      63     92
# 74   11      45      62     13
# 75   53       0      88     61
# 80   36      92      85     90
# 81   90      28      78     58
# 83   57      33      74     10
# 84   18      27      93     88
# 88   81      17      64     73
# 89   44      87      60     67
# 93   60      92      83     62
# 95   54       6      66     93
# 97   23      21      80     33
# 98   55      78      54     54

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1     0       6      97     41
# 5    45      86      95    100
# 10   10      60      77     55
# 13    0      71      98     39
# 16   21      20      58     30
# 17   17      47      54      5
# 19   76     100      89     90
# 21   47      92      71     11
# 25   27      52      62     33
# 26   20      99      83     63
# 28   76      79      88     33
# 29   82      60      51     64
# 33   86      52      79     30
# 35   94      13      51     15
# 36    8      67      78     38
# 38   80      56      88     25
# 39    3      83      85     88
# 40   90     100      99     79
# 43   21       7      67     30
# 50   88      17      89     11
# 51   82      94      63     79
# 52   69      15      83     63
# 53   50       5      97     34
# 54   96      74      80     93
# 57   65      46      67     33
# 58    8      59      84     34
# 59   48       5      96     66
# 60   13      42      83    100
# 61    4      25     100     28
# 65   86      67      68      9
# 70   91      81      77     90
# 71   57      20      91     52
# 73   59      56      63     92
# 74   11      45      62     13
# 75   53       0      88     61
# 80   36      92      85     90
# 81   90      28      78     58
# 83   57      33      74     10
# 84   18      27      93     88
# 88   81      17      64     73
# 89   44      87      60     67
# 93   60      92      83     62
# 95   54       6      66     93
# 97   23      21      80     33
# 98   55      78      54     54

# %%
filter1 = df1['Age'] > 50

# %%
df1[filter1&filter2]
# Out:
#     Age  Height  Weight  Speed
# 19   76     100      89     90
# 28   76      79      88     33
# 29   82      60      51     64
# 33   86      52      79     30
# 35   94      13      51     15
# 38   80      56      88     25
# 40   90     100      99     79
# 50   88      17      89     11
# 51   82      94      63     79
# 52   69      15      83     63
# 54   96      74      80     93
# 57   65      46      67     33
# 65   86      67      68      9
# 70   91      81      77     90
# 71   57      20      91     52
# 73   59      56      63     92
# 75   53       0      88     61
# 81   90      28      78     58
# 83   57      33      74     10
# 88   81      17      64     73
# 93   60      92      83     62
# 95   54       6      66     93
# 98   55      78      54     54

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 19   76     100      89     90
# 28   76      79      88     33
# 29   82      60      51     64
# 33   86      52      79     30
# 35   94      13      51     15
# 38   80      56      88     25
# 40   90     100      99     79
# 50   88      17      89     11
# 51   82      94      63     79
# 52   69      15      83     63
# 54   96      74      80     93
# 57   65      46      67     33
# 65   86      67      68      9
# 70   91      81      77     90
# 71   57      20      91     52
# 73   59      56      63     92
# 75   53       0      88     61
# 81   90      28      78     58
# 83   57      33      74     10
# 88   81      17      64     73
# 93   60      92      83     62
# 95   54       6      66     93
# 98   55      78      54     54
